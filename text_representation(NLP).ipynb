# %% [markdown]
# <a href="https://colab.research.google.com/github/MuizSarwar/Deep-Learning-study-materials-/blob/main/text_representation(NLP).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Bag Of Words

# %%
from sklearn.feature_extraction.text import CountVectorizer
import pandas as pd

# %%
# ==========================================
# 1. Documents (Corpus)
# ==========================================
corpus = [
    "students watch youtube youtube youtube",
    "youtube watch youtube",
    "students write comments",
    "youtube write comments"
]

# %%
cv = CountVectorizer()
X = cv.fit_transform(corpus)

# %%
#show vocabulary
cv.get_feature_names_out()
# Out:
# array(['comments', 'students', 'watch', 'write', 'youtube'], dtype=object)

# %%
#show words matrix
X.toarray()
# Out:
# array([[0, 1, 1, 0, 3],
#        [0, 0, 1, 0, 2],
#        [1, 1, 0, 1, 0],
#        [1, 0, 0, 1, 1]])

# %%
#Dataframe representarion
df = pd.DataFrame(
    X.toarray(),
    index = ['D1','D2','D3','D4'],
    columns = cv.get_feature_names_out()
)

# %% [markdown]
# ##TF-IDF

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
corpus = [
    "students watch youtube",
    "youtube watch youtube",
    "students write comments",
    "youtube write comments"
]

# %%
# ==========================================
# 1. Create Dataset
# ==========================================
df = pd.DataFrame({ "text" : corpus
    ,
    "output": [1, 1, 0, 0]
})

df
# Out:
#                       text  output
# 0   students watch youtube       1
# 1    youtube watch youtube       1
# 2  students write comments       0
# 3   youtube write comments       0

# %%
#TF-IDF vectorizer
tfidf = TfidfVectorizer()

# %%
#Learn Vocabulary + Compute TF-IDF
X = tfidf.fit_transform(df['text'])

# %%
#sparce matrix
X.toarray()
# Out:
# array([[0.        , 0.61366674, 0.61366674, 0.        , 0.49681612],
#        [0.        , 0.        , 0.52546357, 0.        , 0.8508161 ],
#        [0.57735027, 0.57735027, 0.        , 0.57735027, 0.        ],
#        [0.61366674, 0.        , 0.        , 0.61366674, 0.49681612]])

# %%
#features
tfidf.get_feature_names_out()
# Out:
# array(['comments', 'students', 'watch', 'write', 'youtube'], dtype=object)

# %%
##tf-idf matrix
tfidf_matrix = pd.DataFrame(
    X.toarray(),
    columns = tfidf.get_feature_names_out()
)

tfidf_matrix
# Out:
#    comments  students     watch     write   youtube
# 0  0.000000  0.613667  0.613667  0.000000  0.496816
# 1  0.000000  0.000000  0.525464  0.000000  0.850816
# 2  0.577350  0.577350  0.000000  0.577350  0.000000
# 3  0.613667  0.000000  0.000000  0.613667  0.496816
